# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df = pd.read_json('../data/raw/energy_data.json')
df.head()
# Out:
#             timestamp reportingGroup  \
# 0 2020-01-01 00:00:00    Electricity
# 1 2020-01-01 01:00:00    Electricity
# 2 2020-01-01 02:00:00    Electricity
# 3 2020-01-01 03:00:00    Electricity
# 4 2020-01-01 04:00:00    Electricity
#
#                                  locationName  value unit
# 0  3507 Hanuripolku 3, Päiväkoti Les Galopins   2.19  kWh
# 1  3507 Hanuripolku 3, Päiväkoti Les Galopins   2.19  kWh
# 2  3507 Hanuripolku 3, Päiväkoti Les Galopins   2.19  kWh
# 3  3507 Hanuripolku 3, Päiväkoti Les Galopins   2.18  kWh
# 4  3507 Hanuripolku 3, Päiväkoti Les Galopins   2.19  kWh

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40018 entries, 0 to 40017
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       40018 non-null  datetime64[ns]
#  1   reportingGroup  40018 non-null  object
#  2   locationName    40018 non-null  object
#  3   value           40018 non-null  float64
#  4   unit            40018 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# timestamp         0
# reportingGroup    0
# locationName      0
# value             0
# unit              0
# dtype: int64

# %%
df['value'].plot()
# Out:
# <Axes: >
